# %%
from msh_classes import *
import meshio as m
import numpy as np
import matplotlib.pyplot as plt

# %%
msh_name = "./input_data/bay.msh"
msh = m.read(msh_name)
mesh = Mesh(msh)

# %%
mesh.store_coordinates()

# %%
mesh.store_midpoint()

# %%
mesh.find_neighbors()

# %%
mesh.normal()

# %%
mesh.flow_vector()

# %%
x, y = 0.35, 0.45
mesh.initial_oil(x, y)

# %%
mesh.store_area()

# %%
import os

umax = max(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))
umin = min(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))

# Iterate through time steps and plot the mesh
for timestep in range(20):
    # Update oil distribution
    mesh.update_oil(delta_t=0.001)
    print(mesh._cells[600])
# Out:
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]
# Triangle 600, Oil: 0.10109136458301884 Normals:[] Neighbors:[{<msh_classes.Triangle object at 0x000001B90A907020>: [np.int64(1715), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90A907710>: [np.int64(745), np.int64(1237)]}, {<msh_classes.Triangle object at 0x000001B90AAABDD0>: [np.int64(745), np.int64(1715)]}] Velocity:[ 0.43326786 -0.47908484]

# %%
import os

umax = max(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))
umin = min(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))

# Iterate through time steps and plot the mesh
for timestep in range(20):
    # Update oil distribution
    #for i in range(20):
     #   os.remove(f"./images/mesh_timestep_{i}.png")
    
    mesh.update_oil(delta_t=0.001)

    # Create the plot
    plt.figure()
    ax = plt.gca()

    # Create the colormap
    sm = plt.cm.ScalarMappable(cmap="viridis")
    sm.set_array([umin, umax])
    cbar = plt.colorbar(sm, ax=ax, label="Oil Concentration (u)")

    # Plot each triangle with its corresponding color
    for cell in mesh._cells:
        if isinstance(cell, Triangle):
            # Get triangle vertices
            vertices = np.array(cell._coordinates)

            # Get oil concentration `u` for the cell
            u_value = cell.get_amount_of_oil()

            # Normalize u_value for colormap
            normalized_u = (u_value - umin) / (umax - umin)

            # Add the triangle to the plot
            ax.add_patch(
                plt.Polygon(vertices, color=plt.cm.viridis(normalized_u), edgecolor="black", alpha=0.9)
            )

    # Add labels to axes
    plt.xlabel("X-coordinate")
    plt.ylabel("Y-coordinate")
    ax.set_aspect("equal", adjustable="box")

    # Save the plot
    image_path = os.path.join("./images", f"mesh_timestep_{timestep}.png")
    plt.savefig(image_path)

    # Close the plot to avoid memory issues
    plt.close()
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_41392\3526170604.py:37: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.Polygon(vertices, color=plt.cm.viridis(normalized_u), edgecolor="black", alpha=0.9)
