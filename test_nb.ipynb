# %%
from msh_classes import *
import meshio as m
import numpy as np
import matplotlib.pyplot as plt

# %%
msh_name = "./input_data/bay.msh"
msh = m.read(msh_name)
mesh = Mesh(msh)

# %%
mesh.store_coordinates()

# %%
mesh.store_midpoint()

# %%
mesh.find_neighbors()

# %%
mesh.normal()
# Out:
# {<msh_classes.Triangle object at 0x000001D6DBB433E0>: array([0.00803673, 0.01711999])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBC80>: array([ 0.01559162, -0.01652318])}
# {<msh_classes.Triangle object at 0x000001D6DBA04470>: array([-0.02362834, -0.0005968 ])}
# {<msh_classes.Triangle object at 0x000001D6DBB75B50>: array([-0.01490083, -0.01318353])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBCE0>: array([-0.00476838,  0.02191027])}
# {<msh_classes.Triangle object at 0x000001D6DBA041D0>: array([ 0.01966921, -0.00872674])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB920>: array([0.0004917 , 0.02462029])}
# {<msh_classes.Triangle object at 0x000001D6DBA05AC0>: array([ 0.0193693 , -0.01310655])}
# {<msh_classes.Triangle object at 0x000001D6DBA05F10>: array([-0.019861  , -0.01151375])}
# {<msh_classes.Triangle object at 0x000001D6DBA04140>: array([-0.00638006,  0.02127566])}
# {<msh_classes.Triangle object at 0x000001D6DBA04050>: array([ 0.02083568, -0.00822945])}
# {<msh_classes.Triangle object at 0x000001D6DBB75430>: array([-0.01445563, -0.01304621])}
# {<msh_classes.Triangle object at 0x000001D6DBB0F890>: array([-0.01910467,  0.00537781])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBE30>: array([0.01699703, 0.01673148])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBE60>: array([ 0.00210763, -0.02210929])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB800>: array([0.01637424, 0.01546349])}
# {<msh_classes.Triangle object at 0x000001D6DBBE28A0>: array([ 0.00301652, -0.01681642])}
# {<msh_classes.Triangle object at 0x000001D6DBA040E0>: array([-0.01939075,  0.00135293])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB9B0>: array([-0.00383777,  0.02037547])}
# {<msh_classes.Triangle object at 0x000001D6DBAD6CC0>: array([ 0.01989693, -0.00507041])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB8C0>: array([-0.01605915, -0.01530506])}
# {<msh_classes.Triangle object at 0x000001D6DBA05F10>: array([-0.00185266,  0.02090318])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBC50>: array([ 0.02337428, -0.00989319])}
# {<msh_classes.Triangle object at 0x000001D6DBA049E0>: array([-0.02152162, -0.01100999])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBD40>: array([-0.02088974, -0.01107128])}
# {<msh_classes.Triangle object at 0x000001D6DBA04FB0>: array([0.00398924, 0.02098068])}
# {<msh_classes.Triangle object at 0x000001D6DBA6CD40>: array([ 0.0169005, -0.0099094])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB830>: array([0.02194488, 0.01120984])}
# {<msh_classes.Triangle object at 0x000001D6DBA36D20>: array([-0.00088499, -0.02073459])}
# {<msh_classes.Triangle object at 0x000001D6DBA047A0>: array([-0.02105989,  0.00952475])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB8F0>: array([0.01815859, 0.01645123])}
# {<msh_classes.Triangle object at 0x000001D6DBAA0170>: array([ 0.00286113, -0.0212765 ])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB890>: array([-0.02101971,  0.00482527])}
# {<msh_classes.Triangle object at 0x000001D6DBB43620>: array([0.01334418, 0.01471745])}
# {<msh_classes.Triangle object at 0x000001D6DBA04BF0>: array([ 0.00837126, -0.02023548])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBDD0>: array([-0.02171544,  0.00551802])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB6B0>: array([-0.01637424, -0.01546349])}
# {<msh_classes.Triangle object at 0x000001D6DBA05B80>: array([-0.00222213,  0.02122374])}
# {<msh_classes.Triangle object at 0x000001D6DBBE09E0>: array([ 0.01859637, -0.00576025])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB770>: array([-0.02194488, -0.01120984])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0050>: array([0.00432318, 0.02075165])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBAD0>: array([ 0.0176217 , -0.00954181])}
# {<msh_classes.Triangle object at 0x000001D6DBA05010>: array([-0.00246406,  0.02224608])}
# {<msh_classes.Triangle object at 0x000001D6DBA37620>: array([ 0.01943745, -0.00487935])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBD10>: array([-0.0169734 , -0.01736672])}
# {<msh_classes.Triangle object at 0x000001D6DBB0C830>: array([-0.00563926,  0.01985294])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB7A0>: array([ 0.02101971, -0.00482527])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBA10>: array([-0.01538046, -0.01502767])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB6E0>: array([0.01605915, 0.01530506])}
# {<msh_classes.Triangle object at 0x000001D6DBA05CA0>: array([ 0.00494751, -0.02407001])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBF50>: array([-0.02100666,  0.00876495])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB7A0>: array([-0.01815859, -0.01645123])}
# {<msh_classes.Triangle object at 0x000001D6DBA04B90>: array([-0.00107654,  0.02265213])}
# {<msh_classes.Triangle object at 0x000001D6DBAA38C0>: array([ 0.01923513, -0.0062009 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0B60>: array([-0.0134551 ,  0.01317743])}
# {<msh_classes.Triangle object at 0x000001D6DBA359D0>: array([0.0139468 , 0.01144286])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB620>: array([-0.0004917 , -0.02462029])}
# {<msh_classes.Line object at 0x000001D6DB9DABD0>: array([-0.01837567,  0.00726342])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBF50>: array([0.01868265, 0.01335399])}
# {<msh_classes.Triangle object at 0x000001D6DBA04800>: array([-0.00030699, -0.02061742])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBFB0>: array([0.01693578, 0.01576458])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBBF0>: array([ 0.00339242, -0.02021181])}
# {<msh_classes.Triangle object at 0x000001D6DBA06690>: array([-0.0203282 ,  0.00444724])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB6E0>: array([ 0.00383777, -0.02037547])}
# {<msh_classes.Triangle object at 0x000001D6DBB41340>: array([-0.01977317,  0.0049148 ])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBBF0>: array([0.0159354 , 0.01546067])}
# {<msh_classes.Triangle object at 0x000001D6DBB423C0>: array([-0.01736515, -0.0076863 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04950>: array([0.00195499, 0.02270447])}
# {<msh_classes.Triangle object at 0x000001D6DBA044D0>: array([ 0.01541016, -0.01501818])}
# {<msh_classes.Line object at 0x000001D6DB9DACC0>: array([-0.01915623,  0.00484454])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB890>: array([0.01538046, 0.01502767])}
# {<msh_classes.Triangle object at 0x000001D6DBA05C40>: array([ 0.00377577, -0.01987221])}
# {<msh_classes.Triangle object at 0x000001D6DBA6FC80>: array([0.02083314, 0.00032579])}
# {<msh_classes.Triangle object at 0x000001D6DBC14B00>: array([-0.00405791, -0.01816393])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBA70>: array([-0.01677523,  0.01783814])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBA40>: array([ 0.01677523, -0.01783814])}
# {<msh_classes.Triangle object at 0x000001D6DBBE22A0>: array([-0.01901622, -0.00028852])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF8C0>: array([0.002241  , 0.01812666])}
# {<msh_classes.Triangle object at 0x000001D6DBA040B0>: array([-0.00501472,  0.02137684])}
# {<msh_classes.Triangle object at 0x000001D6DBAA2F30>: array([ 0.01874959, -0.00447426])}
# {<msh_classes.Triangle object at 0x000001D6DBA05E50>: array([-0.01373487, -0.01690258])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB830>: array([-0.0176217 ,  0.00954181])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBD70>: array([0.02021854, 0.0104266 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1040>: array([-0.00259684, -0.01996841])}
# {<msh_classes.Line object at 0x000001D6DB9DAE10>: array([-0.01870343,  0.00636984])}
# {<msh_classes.Triangle object at 0x000001D6DBA04080>: array([0.01617382, 0.01578088])}
# {<msh_classes.Triangle object at 0x000001D6DBA04EC0>: array([ 0.00252961, -0.02215072])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBC20>: array([ 0.02047921, -0.01234243])}
# {<msh_classes.Triangle object at 0x000001D6DBA06A50>: array([-0.01646369, -0.00770147])}
# {<msh_classes.Triangle object at 0x000001D6DBB775F0>: array([-0.00401552,  0.0200439 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA047D0>: array([0.02050218, 0.00652112])}
# {<msh_classes.Triangle object at 0x000001D6DBA049B0>: array([-0.00926013, -0.01988889])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2CC0>: array([-0.01124205,  0.01336778])}
# {<msh_classes.Triangle object at 0x000001D6DBB43950>: array([-0.01468152, -0.01335764])}
# {<msh_classes.Triangle object at 0x000001D6DBA04350>: array([-0.00541895,  0.02289986])}
# {<msh_classes.Triangle object at 0x000001D6DBA05100>: array([ 0.02010048, -0.00954222])}
# {<msh_classes.Line object at 0x000001D6DB9DA7B0>: array([-0.01353622,  0.01439447])}
# {<msh_classes.Triangle object at 0x000001D6DBA043B0>: array([0.02232594, 0.00473645])}
# {<msh_classes.Triangle object at 0x000001D6DBA04E90>: array([-0.00878972, -0.01913093])}
# {<msh_classes.Triangle object at 0x000001D6DBAA2720>: array([ 0.01932782, -0.00475114])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB9B0>: array([-0.0159354 , -0.01546067])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB980>: array([-0.00339242,  0.02021181])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBB30>: array([-0.02047921,  0.01234243])}
# {<msh_classes.Triangle object at 0x000001D6DBBE13D0>: array([0.01750485, 0.00500054])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2870>: array([ 0.00297436, -0.01734297])}
# {<msh_classes.Triangle object at 0x000001D6DBA07A10>: array([0.01768205, 0.00899189])}
# {<msh_classes.Triangle object at 0x000001D6DBA04D10>: array([ 0.00569223, -0.01888507])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB710>: array([-0.02337428,  0.00989319])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB5C0>: array([-0.01559162,  0.01652318])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF890>: array([0.01718941, 0.00237509])}
# {<msh_classes.Triangle object at 0x000001D6DBA06A80>: array([-0.0015978 , -0.01889827])}
# {<msh_classes.Triangle object at 0x000001D6DBA05C10>: array([-0.00210428, -0.0217643 ])}
# {<msh_classes.Triangle object at 0x000001D6DBAD7650>: array([-0.01736832,  0.00959498])}
# {<msh_classes.Triangle object at 0x000001D6DBA04A40>: array([0.0194726 , 0.01216931])}
# {<msh_classes.Triangle object at 0x000001D6DBB0F950>: array([-0.01981003,  0.00519968])}
# {<msh_classes.Triangle object at 0x000001D6DBBAEE40>: array([0.01504165, 0.01671059])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB5F0>: array([ 0.00476838, -0.02191027])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB860>: array([0.0169734 , 0.01736672])}
# {<msh_classes.Triangle object at 0x000001D6DBA05880>: array([ 0.00232673, -0.02064328])}
# {<msh_classes.Triangle object at 0x000001D6DBA04DA0>: array([-0.01930013,  0.00327656])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB740>: array([0.02088974, 0.01107128])}
# {<msh_classes.Triangle object at 0x000001D6DBA05FD0>: array([-0.00151493, -0.02018429])}
# {<msh_classes.Triangle object at 0x000001D6DBB77B30>: array([-0.01937482,  0.00911301])}
# {<msh_classes.Triangle object at 0x000001D6DBA06060>: array([0.00396696, 0.02019114])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0E30>: array([ 0.01625158, -0.00976454])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBAD0>: array([-0.02021854, -0.0104266 ])}
# {<msh_classes.Triangle object at 0x000001D6DBB0E1E0>: array([-0.00488682,  0.02017408])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB7D0>: array([ 0.02171544, -0.00551802])}
# {<msh_classes.Triangle object at 0x000001D6DBA05B20>: array([-0.01682862, -0.01465606])}
# {<msh_classes.Line object at 0x000001D6DB9DADB0>: array([-0.01900919,  0.00539178])}
# {<msh_classes.Triangle object at 0x000001D6DBA04DA0>: array([0.01554787, 0.017164  ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04E30>: array([ 0.00346132, -0.02255578])}
# {<msh_classes.Triangle object at 0x000001D6DBA042C0>: array([ 0.01329   , -0.01663397])}
# {<msh_classes.Triangle object at 0x000001D6DBBE25A0>: array([-0.0153387 , -0.00371114])}
# {<msh_classes.Triangle object at 0x000001D6DBA05610>: array([0.0020487, 0.0203451])}
# {<msh_classes.Triangle object at 0x000001D6DBB76B40>: array([-0.00560653,  0.02012079])}
# {<msh_classes.Triangle object at 0x000001D6DBA045F0>: array([ 0.02260356, -0.00338931])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB680>: array([-0.01699703, -0.01673148])}
# {<msh_classes.Triangle object at 0x000001D6DBB766C0>: array([-0.01351707, -0.01218057])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB680>: array([-0.00210763,  0.02210929])}
# {<msh_classes.Triangle object at 0x000001D6DBA058E0>: array([ 0.0156247 , -0.00992872])}
# {<msh_classes.Triangle object at 0x000001D6DBA06000>: array([-0.01791729,  0.00597472])}
# {<msh_classes.Triangle object at 0x000001D6DBA04890>: array([0.01548578, 0.0127599 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1280>: array([ 0.00243151, -0.01873462])}
# {<msh_classes.Triangle object at 0x000001D6DBA044A0>: array([-0.00923805,  0.02097484])}
# {<msh_classes.Triangle object at 0x000001D6DBA04680>: array([ 0.02337011, -0.00339797])}
# {<msh_classes.Triangle object at 0x000001D6DBA04350>: array([-0.01413206, -0.01757687])}
# {<msh_classes.Triangle object at 0x000001D6DBA04F80>: array([ 0.00491783, -0.0180571 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04D40>: array([-0.01952191,  0.00468734])}
# {<msh_classes.Triangle object at 0x000001D6DBBACD40>: array([0.01460407, 0.01336976])}
# {<msh_classes.Triangle object at 0x000001D6DBBE10D0>: array([-0.0091169 , -0.01603482])}
# {<msh_classes.Triangle object at 0x000001D6DBA04110>: array([-0.01021797,  0.01683406])}
# {<msh_classes.Triangle object at 0x000001D6DBBE14C0>: array([ 0.01933487, -0.00079925])}
# {<msh_classes.Triangle object at 0x000001D6DBB40590>: array([-0.00232401,  0.02211895])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB8C0>: array([ 0.02100666, -0.00876495])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB950>: array([-0.01868265, -0.01335399])}
# {<msh_classes.Line object at 0x000001D6DB9DB530>: array([-0.01477031,  0.01312491])}
# {<msh_classes.Triangle object at 0x000001D6DBA050D0>: array([0.01902876, 0.0086138 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04CE0>: array([-0.00425845, -0.0217387 ])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB980>: array([-0.01693578, -0.01576458])}
# {<msh_classes.Triangle object at 0x000001D6DBA05E20>: array([-0.00149267,  0.01994985])}
# {<msh_classes.Triangle object at 0x000001D6DBA05A90>: array([ 0.01842845, -0.00418528])}
# {<msh_classes.Triangle object at 0x000001D6DBA04650>: array([ 0.00046307, -0.02246521])}
# {<msh_classes.Triangle object at 0x000001D6DBA04E30>: array([-0.01741712,  0.00856792])}
# {<msh_classes.Triangle object at 0x000001D6DBA05880>: array([0.01695405, 0.01389729])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB650>: array([-0.02083568,  0.00822945])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1D30>: array([0.0163296 , 0.00719058])}
# {<msh_classes.Triangle object at 0x000001D6DBBE28D0>: array([ 0.00450608, -0.01542003])}
# {<msh_classes.Triangle object at 0x000001D6DBA048C0>: array([-0.00264525,  0.02147576])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0830>: array([ 0.01881907, -0.00569489])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBB00>: array([-0.01617382, -0.01578088])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBAA0>: array([ 0.00501472, -0.02137684])}
# {<msh_classes.Triangle object at 0x000001D6DBA06240>: array([-0.02043835,  0.01047659])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1490>: array([0.01542363, 0.01090025])}
# {<msh_classes.Triangle object at 0x000001D6DBA04AA0>: array([-0.01292714,  0.01689923])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB6B0>: array([ 0.01939075, -0.00135293])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3260>: array([-0.00646361, -0.0155463 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3110>: array([-0.01902971,  0.00111325])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0560>: array([0.00881174, 0.01572081])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBF20>: array([ 0.01021797, -0.01683406])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB650>: array([ 0.00638006, -0.02127566])}
# {<msh_classes.Triangle object at 0x000001D6DBA347A0>: array([-0.02001947,  0.00345674])}
# {<msh_classes.Triangle object at 0x000001D6DBA34DA0>: array([0.01363941, 0.01781891])}
# {<msh_classes.Triangle object at 0x000001D6DBA04CB0>: array([ 0.02131545, -0.00400559])}
# {<msh_classes.Triangle object at 0x000001D6DBA05730>: array([-0.01573302, -0.01491541])}
# {<msh_classes.Triangle object at 0x000001D6DBBAFE30>: array([-0.00558243,  0.01892099])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0EC0>: array([0.01552666, 0.01247975])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0F20>: array([ 0.0052402 , -0.01783008])}
# {<msh_classes.Triangle object at 0x000001D6DBA04770>: array([-0.02076686,  0.00535033])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB5F0>: array([-0.01966921,  0.00872674])}
# {<msh_classes.Triangle object at 0x000001D6DBA07BC0>: array([0.01752442, 0.0069169 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3860>: array([ 0.00214479, -0.01564364])}
# {<msh_classes.Triangle object at 0x000001D6DBA05A60>: array([ 0.01902359, -0.0067063 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA05E20>: array([-0.01624107, -0.01409897])}
# {<msh_classes.Triangle object at 0x000001D6DBA05490>: array([-0.00278251,  0.02080527])}
# {<msh_classes.Triangle object at 0x000001D6DBA04260>: array([-0.01754336,  0.0166506 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE35F0>: array([0.01881374, 0.00209034])}
# {<msh_classes.Triangle object at 0x000001D6DBBE18B0>: array([-0.00127038, -0.01874095])}
# {<msh_classes.Triangle object at 0x000001D6DBA04230>: array([ 0.01754336, -0.0166506 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1940>: array([-0.01900576, -0.00108649])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF7A0>: array([0.0014624 , 0.01773709])}
# {<msh_classes.Triangle object at 0x000001D6DBA06EA0>: array([-0.02198754,  0.00302475])}
# {<msh_classes.Triangle object at 0x000001D6DBA04B30>: array([0.01509842, 0.0166132 ])}
# {<msh_classes.Triangle object at 0x000001D6DBAA0B30>: array([ 0.00688912, -0.01963795])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBE00>: array([-0.01329   ,  0.01663397])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2630>: array([0.01717845, 0.00017838])}
# {<msh_classes.Triangle object at 0x000001D6DBBE13A0>: array([-0.00388844, -0.01681234])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF740>: array([ 0.00272038, -0.02060047])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0620>: array([-0.01805674,  0.00529646])}
# {<msh_classes.Triangle object at 0x000001D6DBA04D70>: array([0.01533636, 0.01530401])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2FF0>: array([ 0.00044711, -0.02082449])}
# {<msh_classes.Triangle object at 0x000001D6DBAD78C0>: array([-0.01800584,  0.00514938])}
# {<msh_classes.Triangle object at 0x000001D6DBA04980>: array([0.01755873, 0.01567511])}
# {<msh_classes.Triangle object at 0x000001D6DBB430B0>: array([-0.01955101,  0.00532299])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBEC0>: array([0.01413206, 0.01757687])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBB90>: array([ 0.00541895, -0.02289986])}
# {<msh_classes.Triangle object at 0x000001D6DBA04AD0>: array([-0.00584488, -0.02085959])}
# {<msh_classes.Triangle object at 0x000001D6DBA34B30>: array([-0.0135845,  0.0142243])}
# {<msh_classes.Triangle object at 0x000001D6DBA355B0>: array([0.01942938, 0.00663529])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBBC0>: array([-0.02232594, -0.00473645])}
# {<msh_classes.Triangle object at 0x000001D6DBA06450>: array([0.0061854 , 0.01924457])}
# {<msh_classes.Triangle object at 0x000001D6DBA365D0>: array([ 0.01614054, -0.01450812])}
# {<msh_classes.Line object at 0x000001D6DB9D9460>: array([ 0.02, -0.  ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2C90>: array([-0.00581021, -0.01374965])}
# {<msh_classes.Line object at 0x000001D6DB9DB590>: array([-0.01418979,  0.01374965])}
# {<msh_classes.Triangle object at 0x000001D6DBA04530>: array([-0.01194724, -0.02069498])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3C20>: array([-0.00673445,  0.01731444])}
# {<msh_classes.Triangle object at 0x000001D6DBBAFBF0>: array([0.01868169, 0.00338054])}
# {<msh_classes.Line object at 0x000001D6DB9D9880>: array([ 0.02, -0.  ])}
# {<msh_classes.Triangle object at 0x000001D6DBA05250>: array([-0.00924301, -0.0179356 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA05220>: array([-0.01075699,  0.0179356 ])}
# {<msh_classes.Line object at 0x000001D6DB9DB320>: array([-0.01065164,  0.01663181])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB5C0>: array([0.02362834, 0.0005968 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA050A0>: array([-0.0129767 , -0.01722862])}
# {<msh_classes.Triangle object at 0x000001D6DBA079B0>: array([-0.02052774,  0.00406378])}
# {<msh_classes.Triangle object at 0x000001D6DBB0DDC0>: array([0.01128969, 0.01691106])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBEC0>: array([ 0.00923805, -0.02097484])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB9E0>: array([-0.01541016,  0.01501818])}
# {<msh_classes.Triangle object at 0x000001D6DBA05D60>: array([0.01871193, 0.00117063])}
# {<msh_classes.Triangle object at 0x000001D6DBA35400>: array([-0.00330177, -0.01618881])}
# {<msh_classes.Triangle object at 0x000001D6DBA04560>: array([ 0.02320467, -0.00569266])}
# {<msh_classes.Triangle object at 0x000001D6DBA34AD0>: array([-0.01775315, -0.01441336])}
# {<msh_classes.Triangle object at 0x000001D6DBB742F0>: array([-0.00545152,  0.02010603])}
# {<msh_classes.Triangle object at 0x000001D6DBA04410>: array([0.01194724, 0.02069498])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0E90>: array([ 0.0060159 , -0.01812125])}
# {<msh_classes.Triangle object at 0x000001D6DBA05A30>: array([-0.01796314, -0.00257372])}
# {<msh_classes.Triangle object at 0x000001D6DBA04500>: array([-0.02320467,  0.00569266])}
# {<msh_classes.Triangle object at 0x000001D6DBA04D40>: array([0.01462049, 0.0144142 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA066C0>: array([ 0.00858417, -0.02010686])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2660>: array([0.01385965, 0.00591687])}
# {<msh_classes.Line object at 0x000001D6DB9DA6F0>: array([ 0.  , -0.02])}
# {<msh_classes.Line object at 0x000001D6DB9DA720>: array([-0.01385965,  0.01408313])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0FB0>: array([0.01578249, 0.00938592])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1550>: array([ 0.00090695, -0.01951667])}
# {<msh_classes.Triangle object at 0x000001D6DBA04C20>: array([-0.01668944,  0.01013075])}
# {<msh_classes.Triangle object at 0x000001D6DBA04620>: array([0.01225882, 0.01697783])}
# {<msh_classes.Triangle object at 0x000001D6DBA06CC0>: array([ 0.01034475, -0.02036714])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBE30>: array([-0.02260356,  0.00338931])}
# {<msh_classes.Triangle object at 0x000001D6DBA045F0>: array([-0.01225882, -0.01697783])}
# {<msh_classes.Triangle object at 0x000001D6DBA075F0>: array([-0.00776642,  0.01826883])}
# {<msh_classes.Triangle object at 0x000001D6DBA36900>: array([ 0.02002523, -0.001291  ])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBFE0>: array([-0.00046307,  0.02246521])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1CA0>: array([ 0.00973895, -0.01006964])}
# {<msh_classes.Triangle object at 0x000001D6DBA06750>: array([-0.00927588, -0.01239557])}
# {<msh_classes.Triangle object at 0x000001D6DBA36690>: array([0.01022919, 0.01856689])}
# {<msh_classes.Triangle object at 0x000001D6DBA04830>: array([ 0.01314092, -0.02196486])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBEC0>: array([-0.02337011,  0.00339797])}
# {<msh_classes.Triangle object at 0x000001D6DBA05160>: array([-0.02116076,  0.00625015])}
# {<msh_classes.Triangle object at 0x000001D6DBA05460>: array([0.01561595, 0.01318014])}
# {<msh_classes.Triangle object at 0x000001D6DBA6E960>: array([ 0.00554482, -0.01943029])}
# {<msh_classes.Triangle object at 0x000001D6DBA04710>: array([ 0.01619587, -0.01593734])}
# {<msh_classes.Triangle object at 0x000001D6DBA34320>: array([-0.01758689, -0.00270169])}
# {<msh_classes.Triangle object at 0x000001D6DBBE15E0>: array([0.00139101, 0.01863903])}
# {<msh_classes.Triangle object at 0x000001D6DBA046E0>: array([-0.01619587,  0.01593734])}
# {<msh_classes.Triangle object at 0x000001D6DBBE15B0>: array([0.0185145, 0.001509 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3A10>: array([-0.00231863, -0.01744633])}
# {<msh_classes.Triangle object at 0x000001D6DBA04D10>: array([-0.02205037,  0.00799215])}
# {<msh_classes.Triangle object at 0x000001D6DBBE01D0>: array([0.01697663, 0.01114938])}
# {<msh_classes.Triangle object at 0x000001D6DBAD4A10>: array([ 0.00507374, -0.01914154])}
# {<msh_classes.Triangle object at 0x000001D6DBA373E0>: array([-0.00714806,  0.01761175])}
# {<msh_classes.Triangle object at 0x000001D6DBA041A0>: array([ 0.02076686, -0.00535033])}
# {<msh_classes.Triangle object at 0x000001D6DBBE32C0>: array([-0.0136188 , -0.01226142])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB770>: array([ 0.02105989, -0.00952475])}
# {<msh_classes.Triangle object at 0x000001D6DBA061E0>: array([-0.017232  , -0.01193539])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF950>: array([-0.00382789,  0.02146015])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBB60>: array([-0.02050218, -0.00652112])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1B50>: array([0.00464189, 0.01676671])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0AD0>: array([ 0.0158603 , -0.01024559])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB950>: array([0.00030699, 0.02061742])}
# {<msh_classes.Triangle object at 0x000001D6DBA06BA0>: array([ 0.01306752, -0.01352977])}
# {<msh_classes.Triangle object at 0x000001D6DBC14920>: array([-0.01337451, -0.00708765])}
# {<msh_classes.Triangle object at 0x000001D6DBA04680>: array([-0.01314092,  0.02196486])}
# {<msh_classes.Triangle object at 0x000001D6DBA05220>: array([ 0.02075699, -0.00061509])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF5F0>: array([-0.00761607, -0.02134977])}
# {<msh_classes.Triangle object at 0x000001D6DBB74A40>: array([ 0.01925529, -0.00462338])}
# {<msh_classes.Triangle object at 0x000001D6DBA05D60>: array([-0.01284628, -0.01728982])}
# {<msh_classes.Triangle object at 0x000001D6DBA059D0>: array([-0.00640901,  0.02191321])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2A50>: array([-0.00131493,  0.01777041])}
# {<msh_classes.Triangle object at 0x000001D6DBC14C80>: array([ 0.01680071, -0.00501051])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBE90>: array([-0.01548578, -0.0127599 ])}
# {<msh_classes.Line object at 0x000001D6DB9DAE40>: array([-0.01843111,  0.00711725])}
# {<msh_classes.Triangle object at 0x000001D6DBA055B0>: array([0.01578586, 0.01435851])}
# {<msh_classes.Triangle object at 0x000001D6DBA04080>: array([ 0.00264525, -0.02147576])}
# {<msh_classes.Triangle object at 0x000001D6DBA05280>: array([-0.02066609,  0.00578383])}
# {<msh_classes.Triangle object at 0x000001D6DBA04E00>: array([0.01602259, 0.01295487])}
# {<msh_classes.Triangle object at 0x000001D6DBAA2120>: array([ 0.0046435, -0.0187387])}
# {<msh_classes.Line object at 0x000001D6DB9D98E0>: array([ 0.02, -0.  ])}
# {<msh_classes.Triangle object at 0x000001D6DBA34EC0>: array([-0.00776362, -0.01892196])}
# {<msh_classes.Triangle object at 0x000001D6DBA04E60>: array([-0.01223638,  0.01892196])}
# {<msh_classes.Triangle object at 0x000001D6DBA067E0>: array([-0.01645301,  0.01154986])}
# {<msh_classes.Triangle object at 0x000001D6DBB42C00>: array([0.018408  , 0.01115461])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB9E0>: array([-0.00195499, -0.02270447])}
# {<msh_classes.Triangle object at 0x000001D6DBA04320>: array([-0.01755873, -0.01567511])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0680>: array([-0.00322198,  0.01781302])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0A70>: array([ 0.02078071, -0.0021379 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA35D90>: array([ 0.00913194, -0.01841433])}
# {<msh_classes.Triangle object at 0x000001D6DBC14E30>: array([-0.01839207, -0.00147456])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBB60>: array([0.00926013, 0.01988889])}
# {<msh_classes.Triangle object at 0x000001D6DBA06900>: array([-0.01749513,  0.00849738])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB710>: array([0.02152162, 0.01100999])}
# {<msh_classes.Triangle object at 0x000001D6DBC14A70>: array([-0.00402649, -0.01950737])}
# {<msh_classes.Triangle object at 0x000001D6DBAD52B0>: array([ 0.00447395, -0.01950475])}
# {<msh_classes.Triangle object at 0x000001D6DBA05F70>: array([-0.01879997,  0.00488568])}
# {<msh_classes.Triangle object at 0x000001D6DBA05670>: array([0.01432602, 0.01461906])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBCB0>: array([-0.0194726 , -0.01216931])}
# {<msh_classes.Triangle object at 0x000001D6DBA35880>: array([0.00130904, 0.01688525])}
# {<msh_classes.Triangle object at 0x000001D6DBBE16D0>: array([ 0.01816356, -0.00471593])}
# {<msh_classes.Line object at 0x000001D6DB9D9610>: array([ 0.02, -0.  ])}
# {<msh_classes.Triangle object at 0x000001D6DBA05370>: array([-0.00999563, -0.01807759])}
# {<msh_classes.Triangle object at 0x000001D6DBA058B0>: array([-0.01000437,  0.01807759])}
# {<msh_classes.Triangle object at 0x000001D6DBB74A10>: array([0.00875161, 0.02145304])}
# {<msh_classes.Triangle object at 0x000001D6DBA040E0>: array([ 0.01292714, -0.01689923])}
# {<msh_classes.Triangle object at 0x000001D6DBA051F0>: array([-0.02167875, -0.00455381])}
# {<msh_classes.Triangle object at 0x000001D6DBA04380>: array([0.00584488, 0.02085959])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3FE0>: array([ 0.00813213, -0.0148873 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA06600>: array([-0.01397701, -0.00597228])}
# {<msh_classes.Triangle object at 0x000001D6DBA6D460>: array([ 0.0053708 , -0.01919171])}
# {<msh_classes.Triangle object at 0x000001D6DBA04E00>: array([-0.02078017,  0.00571982])}
# {<msh_classes.Triangle object at 0x000001D6DBA06000>: array([0.01540937, 0.01347189])}
# {<msh_classes.Triangle object at 0x000001D6DBA04290>: array([-0.01509842, -0.0166132 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBAEBD0>: array([-0.00469638,  0.02188094])}
# {<msh_classes.Triangle object at 0x000001D6DBA05BE0>: array([ 0.0197948 , -0.00526774])}
# {<msh_classes.Triangle object at 0x000001D6DBA06A80>: array([0.01820696, 0.0119637 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA37D40>: array([ 0.00438874, -0.01880474])}
# {<msh_classes.Triangle object at 0x000001D6DBA054C0>: array([-0.0225957 ,  0.00684104])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB8F0>: array([ 0.00107654, -0.02265213])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0BC0>: array([-0.01896813,  0.01238101])}
# {<msh_classes.Triangle object at 0x000001D6DBA06B10>: array([0.01789159, 0.01027113])}
# {<msh_classes.Triangle object at 0x000001D6DBA061B0>: array([-0.0183036 ,  0.01119638])}
# {<msh_classes.Triangle object at 0x000001D6DBA06630>: array([0.01931089, 0.00878761])}
# {<msh_classes.Triangle object at 0x000001D6DBAA1700>: array([-0.00100729, -0.01998399])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB7D0>: array([-0.00837126,  0.02023548])}
# {<msh_classes.Triangle object at 0x000001D6DBBE10A0>: array([ 0.01530379, -0.00312876])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1BE0>: array([-0.00693253, -0.01710672])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2B10>: array([-0.00108106,  0.0193398 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA045C0>: array([ 0.01668944, -0.01013075])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1580>: array([-0.01560838, -0.00920905])}
# {<msh_classes.Triangle object at 0x000001D6DBA05EB0>: array([-0.01143543,  0.01825424])}
# {<msh_classes.Triangle object at 0x000001D6DBAA2360>: array([0.01974192, 0.00112274])}
# {<msh_classes.Triangle object at 0x000001D6DBA36540>: array([-0.00830649, -0.01937698])}
# {<msh_classes.Triangle object at 0x000001D6DBAA2480>: array([ 0.01907773, -0.00524827])}
# {<msh_classes.Triangle object at 0x000001D6DBA05A90>: array([-0.0146494 , -0.01626189])}
# {<msh_classes.Triangle object at 0x000001D6DBA05A60>: array([-0.00442833,  0.02151017])}
# {<msh_classes.Triangle object at 0x000001D6DBA04170>: array([-0.02131545,  0.00400559])}
# {<msh_classes.Triangle object at 0x000001D6DBC144A0>: array([0.00995134, 0.0126833 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA06A20>: array([ 0.01136412, -0.01668889])}
# {<msh_classes.Triangle object at 0x000001D6DBB76F30>: array([-0.01955839, -0.00625272])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBF80>: array([0.00425845, 0.0217387 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA36210>: array([ 0.01529994, -0.01548598])}
# {<msh_classes.Triangle object at 0x000001D6DBA04740>: array([ 0.02205037, -0.00799215])}
# {<msh_classes.Triangle object at 0x000001D6DBA056D0>: array([-0.01635814, -0.01089292])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBC50>: array([-0.00569223,  0.01888507])}
# {<msh_classes.Triangle object at 0x000001D6DBA04560>: array([-0.01462049, -0.0144142 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBAEC60>: array([-0.00490142,  0.01910153])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBEF0>: array([ 0.01952191, -0.00468734])}
# {<msh_classes.Triangle object at 0x000001D6DBAA3DD0>: array([ 0.02023942, -0.00276132])}
# {<msh_classes.Triangle object at 0x000001D6DBA042F0>: array([-0.01533636, -0.01530401])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3770>: array([-0.00490306,  0.01806533])}
# {<msh_classes.Triangle object at 0x000001D6DBAD67E0>: array([-0.00375226,  0.02044055])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBD10>: array([ 0.01930013, -0.00327656])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBDA0>: array([-0.01554787, -0.017164  ])}
# {<msh_classes.Triangle object at 0x000001D6DBA06300>: array([-0.02006832,  0.00575472])}
# {<msh_classes.Triangle object at 0x000001D6DBA34B60>: array([0.01537738, 0.0140577 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA05CD0>: array([ 0.00469094, -0.01981242])}
# {<msh_classes.Triangle object at 0x000001D6DBA048F0>: array([-0.01602259, -0.01295487])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0440>: array([-0.00475758,  0.01867469])}
# {<msh_classes.Triangle object at 0x000001D6DBA04B00>: array([ 0.02078017, -0.00571982])}
# {<msh_classes.Triangle object at 0x000001D6DBAD78F0>: array([-0.0139558 , -0.01398785])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBDA0>: array([-0.00346132,  0.02255578])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBFE0>: array([ 0.01741712, -0.00856792])}
# {<msh_classes.Triangle object at 0x000001D6DBA6FDA0>: array([0.01000449, 0.01828894])}
# {<msh_classes.Triangle object at 0x000001D6DBA04920>: array([ 0.01223638, -0.01892196])}
# {<msh_classes.Triangle object at 0x000001D6DBA06F60>: array([-0.02224088,  0.00063303])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBBC0>: array([0.00878972, 0.01913093])}
# {<msh_classes.Triangle object at 0x000001D6DBB76810>: array([ 0.00671525, -0.01749731])}
# {<msh_classes.Triangle object at 0x000001D6DBBE07A0>: array([-0.01550498, -0.00163361])}
# {<msh_classes.Triangle object at 0x000001D6DBAD67E0>: array([-0.01513344, -0.01463185])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBB00>: array([-0.00252961,  0.02215072])}
# {<msh_classes.Triangle object at 0x000001D6DBA05010>: array([ 0.01766306, -0.00751886])}
# {<msh_classes.Triangle object at 0x000001D6DBA05E80>: array([-0.01795839,  0.00699343])}
# {<msh_classes.Triangle object at 0x000001D6DBA36840>: array([0.01396558, 0.01337479])}
# {<msh_classes.Triangle object at 0x000001D6DBA05C70>: array([ 0.00399281, -0.02036822])}
# {<msh_classes.Triangle object at 0x000001D6DBA35880>: array([ 0.01743966, -0.01175343])}
# {<msh_classes.Triangle object at 0x000001D6DBAD6AB0>: array([-0.01802806, -0.00921945])}
# {<msh_classes.Triangle object at 0x000001D6DBBAFBC0>: array([0.00058841, 0.02097288])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0D70>: array([ 0.00049028, -0.01882681])}
# {<msh_classes.Triangle object at 0x000001D6DBC14DD0>: array([-0.0153571 ,  0.00721245])}
# {<msh_classes.Triangle object at 0x000001D6DBA05400>: array([0.01486682, 0.01161436])}
# {<msh_classes.Triangle object at 0x000001D6DBB0C740>: array([ 0.01833177, -0.00484559])}
# {<msh_classes.Triangle object at 0x000001D6DBC140B0>: array([-0.01341394, -0.01321151])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBEF0>: array([-0.00491783,  0.0180571 ])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB740>: array([-0.00398924, -0.02098068])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2060>: array([-0.01091913,  0.01462135])}
# {<msh_classes.Triangle object at 0x000001D6DBBE11C0>: array([0.01490838, 0.00635933])}
# {<msh_classes.Triangle object at 0x000001D6DBA6C470>: array([ 0.0179235 , -0.00418662])}
# {<msh_classes.Triangle object at 0x000001D6DBC14CB0>: array([-0.01008806, -0.01520299])}
# {<msh_classes.Triangle object at 0x000001D6DBA055E0>: array([-0.00783545,  0.01938962])}
# {<msh_classes.Triangle object at 0x000001D6DB9DB860>: array([ 0.00246406, -0.02224608])}
# {<msh_classes.Triangle object at 0x000001D6DBA04EC0>: array([-0.01766306,  0.00751886])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF980>: array([0.015199  , 0.01472721])}
# {<msh_classes.Triangle object at 0x000001D6DBA05310>: array([0.01506385, 0.01472387])}
# {<msh_classes.Triangle object at 0x000001D6DBA06F00>: array([ 0.00534915, -0.01932009])}
# {<msh_classes.Triangle object at 0x000001D6DBBE27E0>: array([-0.020413  ,  0.00459622])}
# {<msh_classes.Triangle object at 0x000001D6DBBE07D0>: array([-0.00893857, -0.01657878])}
# {<msh_classes.Triangle object at 0x000001D6DBA06180>: array([-0.01026477,  0.01855169])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2510>: array([ 0.01920334, -0.00197291])}
# {<msh_classes.Triangle object at 0x000001D6DBA057F0>: array([-0.02207633,  0.00400769])}
# {<msh_classes.Triangle object at 0x000001D6DBA04470>: array([0.0129767 , 0.01722862])}
# {<msh_classes.Triangle object at 0x000001D6DBA054C0>: array([ 0.00909963, -0.0212363 ])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBF80>: array([-0.01902876, -0.0086138 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0650>: array([0.00140869, 0.01525329])}
# {<msh_classes.Triangle object at 0x000001D6DBA07C80>: array([ 0.01762007, -0.0066395 ])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBB90>: array([-0.02010048,  0.00954222])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF5F0>: array([0.01780254, 0.00732855])}
# {<msh_classes.Triangle object at 0x000001D6DBC141A0>: array([ 0.00229794, -0.01687077])}
# {<msh_classes.Triangle object at 0x000001D6DBA05850>: array([ 0.01020404, -0.01708428])}
# {<msh_classes.Triangle object at 0x000001D6DBA06F30>: array([-0.01987413, -0.00030984])}
# {<msh_classes.Triangle object at 0x000001D6DBA070E0>: array([0.00967009, 0.01739413])}
# {<msh_classes.Triangle object at 0x000001D6DBA046B0>: array([ 0.02116076, -0.00625015])}
# {<msh_classes.Triangle object at 0x000001D6DBA05DF0>: array([-0.01552338, -0.01206414])}
# {<msh_classes.Triangle object at 0x000001D6DBA06F90>: array([-0.00563738,  0.01831428])}
# {<msh_classes.Triangle object at 0x000001D6DBA05340>: array([-0.00666244, -0.02055083])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1910>: array([-0.00980717,  0.01730284])}
# {<msh_classes.Triangle object at 0x000001D6DBA06390>: array([0.01646961, 0.00324798])}
# {<msh_classes.Triangle object at 0x000001D6DBAA0CB0>: array([ 0.01917204, -0.00533805])}
# {<msh_classes.Triangle object at 0x000001D6DBA05BE0>: array([-0.01440469, -0.01399886])}
# {<msh_classes.Triangle object at 0x000001D6DBA05D30>: array([-0.00476735,  0.01933692])}
# {<msh_classes.Line object at 0x000001D6DB9DB3B0>: array([-0.01374836,  0.01419024])}
# {<msh_classes.Triangle object at 0x000001D6DBA04AA0>: array([0.02167875, 0.00455381])}
# {<msh_classes.Triangle object at 0x000001D6DBA06270>: array([-0.00793039, -0.01874405])}
# {<msh_classes.Triangle object at 0x000001D6DBA6FC50>: array([0.01      , 0.01732051])}
# {<msh_classes.Triangle object at 0x000001D6DBA04440>: array([ 0.01075699, -0.0179356 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04830>: array([-0.02075699,  0.00061509])}
# {<msh_classes.Triangle object at 0x000001D6DBA6FDA0>: array([ 0.00999551, -0.01828894])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3170>: array([-0.01923852,  0.00035334])}
# {<msh_classes.Triangle object at 0x000001D6DBA04440>: array([0.00924301, 0.0179356 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA048F0>: array([ 0.02066609, -0.00578383])}
# {<msh_classes.Triangle object at 0x000001D6DBA06210>: array([-0.01579318, -0.01320666])}
# {<msh_classes.Triangle object at 0x000001D6DBA06420>: array([-0.00487291,  0.01899048])}
# {<msh_classes.Triangle object at 0x000001D6DBA05FD0>: array([0.0184832 , 0.01044135])}
# {<msh_classes.Triangle object at 0x000001D6DBBE17C0>: array([ 0.00060383, -0.01995031])}
# {<msh_classes.Triangle object at 0x000001D6DBA06330>: array([-0.01908703,  0.00950896])}
# {<msh_classes.Triangle object at 0x000001D6DBA05820>: array([-0.0031778 , -0.02091793])}
# {<msh_classes.Triangle object at 0x000001D6DBBE13A0>: array([-0.01240485,  0.01124987])}
# {<msh_classes.Triangle object at 0x000001D6DBBE08F0>: array([0.01558265, 0.00966805])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1C10>: array([-0.00330792,  0.02101047])}
# {<msh_classes.Triangle object at 0x000001D6DBAD5100>: array([ 0.01837177, -0.00628661])}
# {<msh_classes.Triangle object at 0x000001D6DBA05040>: array([-0.01506385, -0.01472387])}
# {<msh_classes.Triangle object at 0x000001D6DBA05190>: array([0.00666244, 0.02055083])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3D70>: array([ 0.0100673 , -0.01277305])}
# {<msh_classes.Triangle object at 0x000001D6DBBE23F0>: array([-0.01672975, -0.00777777])}
# {<msh_classes.Triangle object at 0x000001D6DBA064B0>: array([ 0.01016545, -0.01793229])}
# {<msh_classes.Triangle object at 0x000001D6DBBE37D0>: array([-0.02016107, -0.0001453 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04A70>: array([0.00999563, 0.01807759])}
# {<msh_classes.Line object at 0x000001D6DB9DB0B0>: array([-0.00489995,  0.01914197])}
# {<msh_classes.Triangle object at 0x000001D6DBA06420>: array([ 0.02060571, -0.00560666])}
# {<msh_classes.Triangle object at 0x000001D6DBA062D0>: array([-0.01570576, -0.0135353 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA06150>: array([-0.01452312, -0.01501715])}
# {<msh_classes.Triangle object at 0x000001D6DBA06030>: array([-0.00470308,  0.02012418])}
# {<msh_classes.Triangle object at 0x000001D6DBAA3EF0>: array([ 0.0192262 , -0.00510703])}
# {<msh_classes.Triangle object at 0x000001D6DBA05D00>: array([-0.02127455,  0.00833498])}
# {<msh_classes.Triangle object at 0x000001D6DBA05EE0>: array([0.01601841, 0.01121809])}
# {<msh_classes.Triangle object at 0x000001D6DBB77980>: array([ 0.00525613, -0.01955306])}
# {<msh_classes.Triangle object at 0x000001D6DBBE06B0>: array([-0.01622128, -0.01072912])}
# {<msh_classes.Triangle object at 0x000001D6DBA065D0>: array([-0.00060447,  0.02073913])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0800>: array([ 0.01682575, -0.01001001])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2BD0>: array([ 0.01774588, -0.00599707])}
# {<msh_classes.Triangle object at 0x000001D6DBA04F50>: array([-0.01486682, -0.01161436])}
# {<msh_classes.Triangle object at 0x000001D6DBC14D10>: array([-0.00287906,  0.01761143])}
# {<msh_classes.Triangle object at 0x000001D6DBA046B0>: array([-0.01561595, -0.01318014])}
# {<msh_classes.Triangle object at 0x000001D6DBA062D0>: array([-0.00488763,  0.01872432])}
# {<msh_classes.Triangle object at 0x000001D6DBA06210>: array([ 0.02050357, -0.00554418])}
# {<msh_classes.Triangle object at 0x000001D6DBAA0170>: array([0.01650188, 0.01556625])}
# {<msh_classes.Triangle object at 0x000001D6DBA04200>: array([ 0.00278251, -0.02080527])}
# {<msh_classes.Triangle object at 0x000001D6DBA05C40>: array([-0.01928439,  0.00523902])}
# {<msh_classes.Triangle object at 0x000001D6DBA050A0>: array([-0.00909963,  0.0212363 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04B60>: array([ 0.0225957 , -0.00684104])}
# {<msh_classes.Triangle object at 0x000001D6DBB753A0>: array([-0.01349607, -0.01439527])}
# {<msh_classes.Triangle object at 0x000001D6DBA05580>: array([-0.02048349, -0.00656654])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2EA0>: array([0.00039852, 0.0186635 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA06A50>: array([ 0.02008497, -0.01209695])}
# {<msh_classes.Line object at 0x000001D6DB9D96A0>: array([ 0.02, -0.  ])}
# {<msh_classes.Triangle object at 0x000001D6DBA05B50>: array([-0.00977446, -0.01886409])}
# {<msh_classes.Triangle object at 0x000001D6DBA06090>: array([-0.01022554,  0.01886409])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1190>: array([-0.01594812, -0.00962134])}
# {<msh_classes.Triangle object at 0x000001D6DBBAFF20>: array([-0.0024835 ,  0.01887139])}
# {<msh_classes.Triangle object at 0x000001D6DBA063C0>: array([ 0.01843162, -0.00925005])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1790>: array([-0.00528479, -0.01906135])}
# {<msh_classes.Triangle object at 0x000001D6DBB764B0>: array([-0.0151987,  0.0124948])}
# {<msh_classes.Triangle object at 0x000001D6DBA054F0>: array([0.02048349, 0.00656654])}
# {<msh_classes.Triangle object at 0x000001D6DBAD5EB0>: array([-0.0025087 ,  0.01977328])}
# {<msh_classes.Triangle object at 0x000001D6DBA07BF0>: array([ 0.01829456, -0.00541477])}
# {<msh_classes.Triangle object at 0x000001D6DBA048C0>: array([-0.01578586, -0.01435851])}
# {<msh_classes.Triangle object at 0x000001D6DBA04FE0>: array([ 0.00783545, -0.01938962])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2600>: array([-0.01786671,  0.0069999 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA06EA0>: array([0.01003126, 0.01238972])}
# {<msh_classes.Triangle object at 0x000001D6DBA05C70>: array([0.01613854, 0.01235925])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBE00>: array([-0.0020487, -0.0203451])}
# {<msh_classes.Triangle object at 0x000001D6DBC145C0>: array([-0.01408985,  0.00798586])}
# {<msh_classes.Line object at 0x000001D6DB9DAF60>: array([-0.01183296,  0.01581501])}
# {<msh_classes.Triangle object at 0x000001D6DBA056A0>: array([0.02143161, 0.00344032])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2E10>: array([-0.00959866, -0.01925533])}
# {<msh_classes.Triangle object at 0x000001D6DBA06150>: array([ 0.01970601, -0.00373773])}
# {<msh_classes.Triangle object at 0x000001D6DBA04A10>: array([-0.01432602, -0.01461906])}
# {<msh_classes.Triangle object at 0x000001D6DBBAFEC0>: array([-0.00537999,  0.0183568 ])}
# {<msh_classes.Triangle object at 0x000001D6DBAD7AD0>: array([0.00749871, 0.01876148])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1160>: array([ 0.0139329 , -0.01532117])}
# {<msh_classes.Triangle object at 0x000001D6DBA05640>: array([-0.02143161, -0.00344032])}
# {<msh_classes.Triangle object at 0x000001D6DBA6D8B0>: array([ 0.00507029, -0.01913873])}
# {<msh_classes.Triangle object at 0x000001D6DBA05760>: array([-0.02142843,  0.00824581])}
# {<msh_classes.Triangle object at 0x000001D6DBA04D10>: array([0.01635814, 0.01089292])}
# {<msh_classes.Triangle object at 0x000001D6DBA6F620>: array([-0.01394484, -0.0135908 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBAECC0>: array([-0.00684789,  0.01810236])}
# {<msh_classes.Triangle object at 0x000001D6DBA05790>: array([ 0.02079273, -0.00451156])}
# {<msh_classes.Triangle object at 0x000001D6DBAD71A0>: array([ 0.0029362 , -0.02184175])}
# {<msh_classes.Triangle object at 0x000001D6DBBE21E0>: array([-0.01866923,  0.00692635])}
# {<msh_classes.Triangle object at 0x000001D6DBA04170>: array([0.01573302, 0.01491541])}
# {<msh_classes.Triangle object at 0x000001D6DBA056D0>: array([ 0.02142843, -0.00824581])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3C50>: array([-0.01353767, -0.00524613])}
# {<msh_classes.Triangle object at 0x000001D6DBC14A70>: array([-0.00789076,  0.01349194])}
# {<msh_classes.Triangle object at 0x000001D6DBA05700>: array([-0.02079273,  0.00451156])}
# {<msh_classes.Triangle object at 0x000001D6DBA07440>: array([0.01731269, 0.01350443])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2C30>: array([ 0.00348004, -0.01801598])}
# ...
# {<msh_classes.Triangle object at 0x000001D6DBB41E80>: array([-0.01672143, -0.01342934])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3E00>: array([0.00086405, 0.01657273])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0680>: array([ 0.01585738, -0.0031434 ])}
# {<msh_classes.Triangle object at 0x000001D6DBB423C0>: array([0.00182997, 0.01946876])}
# {<msh_classes.Triangle object at 0x000001D6DBA06840>: array([ 0.01208525, -0.01079145])}
# {<msh_classes.Triangle object at 0x000001D6DBC14D40>: array([-0.01391521, -0.0086773 ])}
# {<msh_classes.Triangle object at 0x000001D6DBAD54F0>: array([0.00848968, 0.01729022])}
# {<msh_classes.Triangle object at 0x000001D6DBBAD2E0>: array([ 0.00686101, -0.01422329])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3E00>: array([-0.01535069, -0.00306693])}
# {<msh_classes.Triangle object at 0x000001D6DBB409E0>: array([-0.01300955,  0.01750724])}
# {<msh_classes.Triangle object at 0x000001D6DBC14DA0>: array([ 0.01715591, -0.00173405])}
# {<msh_classes.Triangle object at 0x000001D6DBC14170>: array([-0.00414636, -0.01577319])}
# {<msh_classes.Triangle object at 0x000001D6DBAA0380>: array([0.01976501, 0.00138326])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3560>: array([-0.00960312, -0.01313196])}
# {<msh_classes.Triangle object at 0x000001D6DBC14B00>: array([-0.01016189,  0.0117487 ])}
# {<msh_classes.Triangle object at 0x000001D6DBAD7E60>: array([-0.0051438 ,  0.01905389])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1F70>: array([ 0.01509514, -0.00637059])}
# {<msh_classes.Triangle object at 0x000001D6DBA04CB0>: array([-0.00995134, -0.0126833 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA36270>: array([ 0.00589961, -0.01947447])}
# {<msh_classes.Triangle object at 0x000001D6DBA34B60>: array([-0.01513124,  0.00666398])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1CD0>: array([0.00923163, 0.01281048])}
# {<msh_classes.Triangle object at 0x000001D6DBA36CF0>: array([ 0.01921321, -0.00439742])}
# {<msh_classes.Triangle object at 0x000001D6DBBE11F0>: array([-0.0131545 , -0.00917383])}
# {<msh_classes.Triangle object at 0x000001D6DBC14CB0>: array([-0.00605871,  0.01357125])}
# {<msh_classes.Triangle object at 0x000001D6DBB0CA40>: array([-0.01956444,  0.00424412])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2030>: array([0.01290944, 0.00953302])}
# {<msh_classes.Triangle object at 0x000001D6DBA060F0>: array([ 0.00665499, -0.01377714])}
# {<msh_classes.Triangle object at 0x000001D6DBAA0C80>: array([ 0.01923894, -0.00471828])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3F80>: array([-0.01190321, -0.00883009])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3E90>: array([-0.00733573,  0.01354837])}
# {<msh_classes.Triangle object at 0x000001D6DBB0C560>: array([-0.02043338,  0.00561656])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2FF0>: array([0.0127354 , 0.00898808])}
# {<msh_classes.Triangle object at 0x000001D6DBC14AA0>: array([ 0.00769797, -0.01460464])}
# {<msh_classes.Triangle object at 0x000001D6DBA07EC0>: array([-0.00511554,  0.01998877])}
# {<msh_classes.Triangle object at 0x000001D6DBA05610>: array([ 0.01408985, -0.00798586])}
# {<msh_classes.Triangle object at 0x000001D6DBBE26F0>: array([-0.0089743 , -0.01200291])}
# {<msh_classes.Triangle object at 0x000001D6DBBAFCE0>: array([ 0.00679466, -0.01678234])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3B90>: array([-0.0155929 ,  0.00282752])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3D70>: array([0.00879825, 0.01395483])}
# {<msh_classes.Triangle object at 0x000001D6DBAD5070>: array([ 0.00491126, -0.01914541])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1FD0>: array([-0.01440257,  0.00651219])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2000>: array([0.00949131, 0.01263321])}
# {<msh_classes.Triangle object at 0x000001D6DBB75220>: array([-0.019115  ,  0.00409262])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2240>: array([0.01261867, 0.00981786])}
# {<msh_classes.Triangle object at 0x000001D6DBA05F40>: array([ 0.00649633, -0.01391048])}
# {<msh_classes.Line object at 0x000001D6DB9DAED0>: array([-0.01620669,  0.01128103])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3080>: array([0.01460083, 0.00351739])}
# {<msh_classes.Triangle object at 0x000001D6DBC14B60>: array([ 0.00160586, -0.01479843])}
# {<msh_classes.Line object at 0x000001D6DB9D9910>: array([ 0.02, -0.  ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1F10>: array([-0.00940286, -0.01231657])}
# {<msh_classes.Triangle object at 0x000001D6DBA34EC0>: array([-0.01059714,  0.01231657])}
# {<msh_classes.Triangle object at 0x000001D6DBA6E510>: array([ 0.00554284, -0.01893421])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3CE0>: array([-0.014434  ,  0.00632111])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1EE0>: array([0.00889116, 0.0126131 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA6DC10>: array([0.01918681, 0.00032673])}
# {<msh_classes.Triangle object at 0x000001D6DBC14D70>: array([-0.00952626, -0.01251124])}
# {<msh_classes.Triangle object at 0x000001D6DBA36540>: array([-0.00966055,  0.0121845 ])}
# {<msh_classes.Triangle object at 0x000001D6DBB0EA20>: array([-0.00616934,  0.01904385])}
# {<msh_classes.Triangle object at 0x000001D6DBBE20F0>: array([ 0.01434799, -0.0063267 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0E00>: array([-0.00817865, -0.01271715])}
# {<msh_classes.Triangle object at 0x000001D6DBAD47A0>: array([ 6.37185431e-05, -1.96928790e-02])}
# {<msh_classes.Triangle object at 0x000001D6DBA06630>: array([-0.01245016,  0.00991452])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1FA0>: array([0.01238644, 0.00977836])}
# {<msh_classes.Triangle object at 0x000001D6DBB0C5F0>: array([-0.01894619,  0.00468674])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF740>: array([0.0125254 , 0.00948982])}
# {<msh_classes.Triangle object at 0x000001D6DBBE20C0>: array([ 0.00642079, -0.01417657])}
# {<msh_classes.Triangle object at 0x000001D6DBAA2060>: array([0.0199995 , 0.00110988])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1F40>: array([-0.00978555, -0.01233249])}
# {<msh_classes.Triangle object at 0x000001D6DBB77590>: array([-0.01021395,  0.0112226 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA6CD40>: array([-0.01724625, -0.00947247])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3320>: array([0.00296102, 0.01423945])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3FB0>: array([ 0.01428523, -0.00476698])}
# {<msh_classes.Triangle object at 0x000001D6DBB40350>: array([-0.00497238,  0.01925102])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2180>: array([ 0.01506265, -0.00593513])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2210>: array([-0.01009028, -0.01331589])}
# {<msh_classes.Triangle object at 0x000001D6DBB0EA50>: array([-0.01900472,  0.00627765])}
# {<msh_classes.Triangle object at 0x000001D6DBBE08C0>: array([0.01282578, 0.0081299 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2120>: array([ 0.00617894, -0.01440755])}
# {<msh_classes.Triangle object at 0x000001D6DBBAF140>: array([-0.02121523,  0.00714299])}
# {<msh_classes.Triangle object at 0x000001D6DBC14B00>: array([0.0142198 , 0.00641523])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3D10>: array([ 0.00699543, -0.01355822])}
# {<msh_classes.Triangle object at 0x000001D6DBB43920>: array([-0.0056087 ,  0.01911197])}
# {<msh_classes.Triangle object at 0x000001D6DBC14B30>: array([ 0.01348553, -0.00650646])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1B20>: array([-0.00787683, -0.01260551])}
# {<msh_classes.Triangle object at 0x000001D6DBAD4650>: array([-0.00107335, -0.01899497])}
# {<msh_classes.Triangle object at 0x000001D6DBA07650>: array([-0.01191524,  0.00937739])}
# {<msh_classes.Triangle object at 0x000001D6DBC14E60>: array([0.01298859, 0.00961758])}
# {<msh_classes.Line object at 0x000001D6DB9DABA0>: array([-0.01837392,  0.0072685 ])}
# {<msh_classes.Triangle object at 0x000001D6DBA04800>: array([0.01337451, 0.00708765])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1E50>: array([ 0.00499941, -0.01435615])}
# {<msh_classes.Line object at 0x000001D6DB9DAD20>: array([-0.01917094,  0.00478608])}
# {<msh_classes.Triangle object at 0x000001D6DBC142C0>: array([0.01197045, 0.00767025])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1EB0>: array([ 0.0072005 , -0.01245633])}
# {<msh_classes.Triangle object at 0x000001D6DBA059A0>: array([-0.01585534,  0.01008929])}
# {<msh_classes.Triangle object at 0x000001D6DBBE30B0>: array([0.01472144, 0.0065703 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2CF0>: array([ 0.0011339 , -0.01665958])}
# {<msh_classes.Triangle object at 0x000001D6DBB75D60>: array([-0.00448807,  0.01944399])}
# {<msh_classes.Triangle object at 0x000001D6DBA36960>: array([ 0.01254634, -0.00698003])}
# {<msh_classes.Triangle object at 0x000001D6DBC14080>: array([-0.00805827, -0.01246396])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3350>: array([0.00613009, 0.01575571])}
# {<msh_classes.Triangle object at 0x000001D6DBBE24E0>: array([ 0.00910797, -0.01314574])}
# {<msh_classes.Triangle object at 0x000001D6DBC14A40>: array([-0.01523806, -0.00260997])}
# {<msh_classes.Triangle object at 0x000001D6DBA05C10>: array([-0.01543759,  0.01249918])}
# {<msh_classes.Triangle object at 0x000001D6DBC14230>: array([0.01719542, 0.00347339])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3EF0>: array([-0.00175783, -0.01597257])}
# {<msh_classes.Triangle object at 0x000001D6DBBAD580>: array([-0.01519819,  0.01223908])}
# {<msh_classes.Triangle object at 0x000001D6DBC149E0>: array([0.01523806, 0.00260997])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3B60>: array([-3.98671875e-05, -1.48490555e-02])}
# {<msh_classes.Triangle object at 0x000001D6DBA049E0>: array([0.00402649, 0.01950737])}
# {<msh_classes.Triangle object at 0x000001D6DBA05760>: array([ 0.00789076, -0.01349194])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3DD0>: array([-0.01191725, -0.00601543])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0F50>: array([-0.00800693, -0.01506502])}
# {<msh_classes.Triangle object at 0x000001D6DBC14590>: array([-0.00769797,  0.01460464])}
# {<msh_classes.Triangle object at 0x000001D6DBC14E00>: array([0.01570491, 0.00046038])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2150>: array([-0.01491638, -0.01342265])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1D00>: array([-0.00327766,  0.01711533])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3770>: array([ 0.01819403, -0.00369267])}
# {<msh_classes.Triangle object at 0x000001D6DB9DBA40>: array([0.00405791, 0.01816393])}
# {<msh_classes.Triangle object at 0x000001D6DBC14470>: array([ 0.01016189, -0.0117487 ])}
# {<msh_classes.Triangle object at 0x000001D6DBC14890>: array([-0.0142198 , -0.00641523])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2990>: array([0.01203307, 0.01069165])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2E70>: array([ 0.00145247, -0.01719811])}
# {<msh_classes.Triangle object at 0x000001D6DBC148C0>: array([-0.01348553,  0.00650646])}
# {<msh_classes.Triangle object at 0x000001D6DBBE37A0>: array([-0.01426697, -0.00906776])}
# {<msh_classes.Triangle object at 0x000001D6DBC14680>: array([-0.00160586,  0.01479843])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3050>: array([ 0.01587283, -0.00573067])}
# {<msh_classes.Triangle object at 0x000001D6DBBE02F0>: array([ 0.00071637, -0.02015821])}
# {<msh_classes.Triangle object at 0x000001D6DBA06660>: array([-0.01382377,  0.01009701])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2F90>: array([0.01310739, 0.0100612 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0CB0>: array([ 0.00694187, -0.01605567])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3860>: array([-0.01645275,  0.00332306])}
# {<msh_classes.Triangle object at 0x000001D6DBC142F0>: array([0.00951088, 0.01273261])}
# {<msh_classes.Triangle object at 0x000001D6DBBE26C0>: array([-0.01738665,  0.00890385])}
# {<msh_classes.Triangle object at 0x000001D6DBC14050>: array([0.01404358, 0.00809579])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2DE0>: array([ 0.00334307, -0.01699965])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2300>: array([-0.00157489, -0.01829131])}
# {<msh_classes.Triangle object at 0x000001D6DBBE0B00>: array([-0.01204248,  0.01008843])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2C00>: array([0.01361736, 0.00820289])}
# {<msh_classes.Triangle object at 0x000001D6DBA36090>: array([-0.00219816,  0.01654052])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2750>: array([ 0.01557267, -0.00877347])}
# {<msh_classes.Triangle object at 0x000001D6DBA063F0>: array([-0.01337452, -0.00776705])}
# {<msh_classes.Triangle object at 0x000001D6DBA04890>: array([-0.01680071,  0.00501051])}
# {<msh_classes.Triangle object at 0x000001D6DBC14260>: array([0.01443356, 0.00978111])}
# {<msh_classes.Triangle object at 0x000001D6DBC14EC0>: array([ 0.00236715, -0.01479162])}
# {<msh_classes.Triangle object at 0x000001D6DBA04FE0>: array([0.01008806, 0.01520299])}
# {<msh_classes.Triangle object at 0x000001D6DBC14500>: array([ 0.00605871, -0.01357125])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3A70>: array([-0.01614676, -0.00163174])}
# {<msh_classes.Triangle object at 0x000001D6DBBE30E0>: array([-0.00316788,  0.01841311])}
# {<msh_classes.Triangle object at 0x000001D6DBBE1A90>: array([ 0.01650863, -0.0079637 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2750>: array([-0.01334075, -0.01044941])}
# {<msh_classes.Triangle object at 0x000001D6DBA05400>: array([ 0.00287906, -0.01761143])}
# {<msh_classes.Triangle object at 0x000001D6DBA06AE0>: array([-0.01386164,  0.00551736])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3FE0>: array([0.01098258, 0.01209407])}
# {<msh_classes.Triangle object at 0x000001D6DBA07440>: array([-0.01655267,  0.00805954])}
# {<msh_classes.Triangle object at 0x000001D6DBC143E0>: array([0.01391521, 0.0086773 ])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3F20>: array([ 0.00263745, -0.01673684])}
# {<msh_classes.Triangle object at 0x000001D6DBBE29C0>: array([ 0.00714518, -0.01592698])}
# {<msh_classes.Triangle object at 0x000001D6DBBE38F0>: array([-0.01667144,  0.00341574])}
# {<msh_classes.Triangle object at 0x000001D6DBC14710>: array([0.00952626, 0.01251124])}
# {<msh_classes.Triangle object at 0x000001D6DBA06AE0>: array([0.01396365, 0.01381813])}
# {<msh_classes.Triangle object at 0x000001D6DBC14DD0>: array([ 0.00319226, -0.01555217])}
# {<msh_classes.Triangle object at 0x000001D6DBC14440>: array([-0.01715591,  0.00173405])}
# {<msh_classes.Triangle object at 0x000001D6DBA04F50>: array([ 0.0153571 , -0.00721245])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2450>: array([-0.01216484, -0.00833972])}
# {<msh_classes.Triangle object at 0x000001D6DBC14DA0>: array([-0.00319226,  0.01555217])}
# {<msh_classes.Triangle object at 0x000001D6DBC14380>: array([ 0.00797329, -0.0134174 ])}
# {<msh_classes.Triangle object at 0x000001D6DBC14AA0>: array([-0.01570491, -0.00046038])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3C80>: array([0.00773162, 0.01387777])}
# {<msh_classes.Triangle object at 0x000001D6DBA049B0>: array([0.01839207, 0.00147456])}
# {<msh_classes.Triangle object at 0x000001D6DBC14350>: array([-0.00860224, -0.01403864])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3E60>: array([-0.00978983,  0.01256408])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3380>: array([ 0.01573445, -0.0063453 ])}
# {<msh_classes.Triangle object at 0x000001D6DBC148F0>: array([-0.01298859, -0.00961758])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3890>: array([-0.00274586,  0.01596288])}
# {<msh_classes.Triangle object at 0x000001D6DBBE2360>: array([ 0.01620928, -0.00644593])}
# {<msh_classes.Triangle object at 0x000001D6DBC14110>: array([-0.01327925, -0.00902876])}
# {<msh_classes.Triangle object at 0x000001D6DBC140B0>: array([-0.00293003,  0.01547469])}
# {<msh_classes.Triangle object at 0x000001D6DBBE33B0>: array([-0.01284543, -0.0136384 ])}
# {<msh_classes.Triangle object at 0x000001D6DBC14C80>: array([-0.00236715,  0.01479162])}
# {<msh_classes.Triangle object at 0x000001D6DBBE3D40>: array([ 0.01521258, -0.00115323])}

# %%
mesh.flow_vector()

# %%
x, y = 0.35, 0.45
mesh.initial_oil(x, y)

# %%
mesh.store_area()

# %%
import os

umax = max(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))
umin = min(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))

# Iterate through time steps and plot the mesh
for timestep in range(20):
    # Update oil distribution
    mesh.update_oil(delta_t=0.001)
    print(mesh._cells[600])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       6 # Iterate through time steps and plot the mesh
#       7 for timestep in range(20):
#       8     # Update oil distribution
# ----> 9     mesh.update_oil(delta_t=0.001)
#      10     print(mesh._cells[600])
#
# File c:\Users\elias\OneDrive - Norwegian University of Life Sciences\INF202\computational-mesh\msh_classes.py:229, in Mesh.update_oil(self, delta_t)
#     226 for cell in self._cells:
#     227     if isinstance(cell, Triangle):
# --> 229         cell.up(delta_t, self._cells)
#
# File c:\Users\elias\OneDrive - Norwegian University of Life Sciences\INF202\computational-mesh\msh_classes.py:151, in Triangle.up(self, delta_t, mesh_cells)
#     149         continue
#     150     v = 0.5 * (self._v + list(ngh.keys())[i]._v)
# --> 151     up += up - delta_t / self._area * flux(self.get_amount_of_oil(),list(ngh.keys())[i]._u, list(ngh_norm.keys())[i], v)
#     153 self._u = self._u + up
#
# File c:\Users\elias\OneDrive - Norwegian University of Life Sciences\INF202\computational-mesh\msh_classes.py:162, in flux(u_i, u_ngh, norm, v)
#     155 def flux(u_i, u_ngh, norm, v):
#     156     """
#     157     u_i: amount of oil in cell i at time t_n
#     158     u_ngh: amount of oil in cell ngh at time t_n
#     159     norm: normal of cell i at edge e
#     160     v: velocity field at edge e
#     161     """
# --> 162     if np.dot(v, norm) > 0:
#     163         return u_i * np.dot(v , norm)
#     164     else:
#
# TypeError: unsupported operand type(s) for *: 'float' and 'Triangle'

# %%
import os

umax = max(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))
umin = min(cell.get_amount_of_oil() for cell in mesh._cells if isinstance(cell, Triangle))

# Iterate through time steps and plot the mesh
for timestep in range(20):
    # Update oil distribution
    #for i in range(20):
     #   os.remove(f"./images/mesh_timestep_{i}.png")
    
    mesh.update_oil(delta_t=0.001)

    # Create the plot
    plt.figure()
    ax = plt.gca()

    # Create the colormap
    sm = plt.cm.ScalarMappable(cmap="viridis")
    sm.set_array([umin, umax])
    cbar = plt.colorbar(sm, ax=ax, label="Oil Concentration (u)")

    # Plot each triangle with its corresponding color
    for cell in mesh._cells:
        if isinstance(cell, Triangle):
            # Get triangle vertices
            vertices = np.array(cell._coordinates)

            # Get oil concentration `u` for the cell
            u_value = cell.get_amount_of_oil()

            # Normalize u_value for colormap
            normalized_u = (u_value - umin) / (umax - umin)

            # Add the triangle to the plot
            ax.add_patch(
                plt.Polygon(vertices, color=plt.cm.viridis(normalized_u), edgecolor="black", alpha=0.9)
            )

    # Add labels to axes
    plt.xlabel("X-coordinate")
    plt.ylabel("Y-coordinate")
    ax.set_aspect("equal", adjustable="box")

    # Save the plot
    image_path = os.path.join("./images", f"mesh_timestep_{timestep}.png")
    plt.savefig(image_path)

    # Close the plot to avoid memory issues
    plt.close()
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_41392\3526170604.py:37: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.Polygon(vertices, color=plt.cm.viridis(normalized_u), edgecolor="black", alpha=0.9)
