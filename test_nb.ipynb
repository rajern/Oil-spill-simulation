# %%
from msh_classes import *
import meshio as m
import numpy as np
import matplotlib.pyplot as plt

# %%
msh_name = "./input_data/bay.msh"
msh = m.read(msh_name)
mesh = Mesh(msh)

# %%
mesh.store_coordinates()

# %%
mesh.store_midpoint()

# %%
mesh.normal()

# %%
mesh.find_neighbors()

# %%
mesh.flow_vector()

# %%
x, y = 0.35, 0.45
mesh.initial_oil(x, y)

# %%
mesh.store_area()

# %%
mesh.update_oil(0.0001)

# %%
mesh.
